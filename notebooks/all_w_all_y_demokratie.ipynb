# %% [markdown]
# # Processing Vectors for Analysis (out of many Dataframe)
# ### Demokratie

# %% [markdown]
# - Loading the Data
# - Creating a Dataframe with every WOI and its yearly mean vectors
# - Creating a similarity matrix for WOI to the TARGET WORD and its visualization
# - Creating a Dataframe with every WOI and its decade mean vectors
# - Creating a similarity matrix with decade mean vectors for WOI to the oneself and its visualization

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Data Managing

# %% [markdown]
# ##### 1.1. Loading the DataFrames

# %%
df_vecs_democracy = pd.read_csv("df_demokratie/df_vecs_democracy.csv")
df_vecs_marktwirtschaft = pd.read_csv("df_demokratie/df_vecs_marktwirtschaft.csv")
df_vecs_liberalismus = pd.read_csv("df_demokratie/df_vecs_liberalismus.csv")
df_vecs_rechtsstaat = pd.read_csv("df_demokratie/df_vecs_rechtsstaat.csv")
df_vecs_sozialismus = pd.read_csv("df_demokratie/df_vecs_sozialismus.csv")
df_vecs_kapitalismus = pd.read_csv("df_demokratie/df_vecs_kapitalismus.csv")
df_vecs_solidarität = pd.read_csv("df_demokratie/df_vecs_solidarität.csv")
df_vecs_federalism =pd.read_csv("df_demokratie/df_vecs_federalism.csv")
df_vecs_nationalismus = pd.read_csv("df_demokratie/df_vecs_nationalismus.csv")
df_vecs_kommunismus =pd.read_csv("df_demokratie/df_vecs_kommunismus.csv")
df_vecs_gerechtigkeit = pd.read_csv("df_demokratie/df_vecs_gerechtigkeit.csv")
df_vecs_diktatur = pd.read_csv("df_demokratie/df_vecs_diktatur.csv")
df_vecs_ideologie = pd.read_csv("df_demokratie/df_vecs_ideologie.csv")
df_vecs_grundeinkommen = pd.read_csv("df_demokratie/df_vecs_grundeinkommen.csv")
df_vecs_extremism =pd.read_csv("df_demokratie/df_vecs_extremism.csv")
df_vecs_toleranz = pd.read_csv("df_demokratie/df_vecs_toleranz.csv")
df_vecs_freedom = pd.read_csv("df_demokratie/df_vecs_freedom.csv")
df_vecs_imperialismus = pd.read_csv("df_demokratie/df_vecs_imperialismus.csv")
df_vecs_globalisierung = pd.read_csv("df_demokratie/df_vecs_globalisierung.csv")
df_vecs_pluralismus = pd.read_csv("df_demokratie/df_vecs_pluralismus.csv")
df_vecs_klassenkampf = pd.read_csv("df_demokratie/df_vecs_klassenkampf.csv")
df_vecs_sozialstaat = pd.read_csv("df_demokratie/df_vecs_sozialstaat.csv")
df_vecs_revolutionäre = pd.read_csv("df_demokratie/df_vecs_revolutionäre.csv")
df_vecs_pazifismus = pd.read_csv("df_demokratie/df_vecs_pazifismus.csv")
df_vecs_anarchismus = pd.read_csv("df_demokratie/df_vecs_anarchismus.csv")
df_vecs_diskurs = pd.read_csv("df_demokratie/df_vecs_diskurs.csv")
df_vecs_konservatismus = pd.read_csv("df_demokratie/df_vecs_konservatismus.csv")

# %%
#converting the rows "RechtsStaat" into right spelling for it not caring any contextual value and just beeing misspeled
df_vecs_rechtsstaat.loc[df_vecs_rechtsstaat["word"] == "RechtsStaat", "word"] = "Rechtsstaat"

# %%
#converting the rows "demokratie" into right spelling for it not caring any contextual value and just beeing misspeled
df_vecs_democracy.loc[df_vecs_democracy["word"] == "demokratie", "word"] = "Demokratie"

# %% [markdown]
# #### 1.2. Converting the list of vectors to a float

# %%
import ast

df_vecs_democracy['vector'] = df_vecs_democracy['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_marktwirtschaft['vector'] = df_vecs_marktwirtschaft['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_liberalismus['vector'] = df_vecs_liberalismus['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_rechtsstaat['vector'] = df_vecs_rechtsstaat['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_sozialismus['vector'] = df_vecs_sozialismus['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_kapitalismus['vector'] = df_vecs_kapitalismus['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_solidarität['vector'] = df_vecs_solidarität['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_federalism['vector'] = df_vecs_federalism['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_nationalismus['vector'] = df_vecs_nationalismus['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_kommunismus['vector'] = df_vecs_kommunismus['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_gerechtigkeit['vector'] = df_vecs_gerechtigkeit['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_diktatur['vector'] = df_vecs_diktatur['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_ideologie['vector'] = df_vecs_ideologie['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_grundeinkommen['vector'] = df_vecs_grundeinkommen['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_extremism['vector'] = df_vecs_extremism['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_toleranz['vector'] = df_vecs_toleranz['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_freedom['vector'] = df_vecs_freedom['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_imperialismus['vector'] = df_vecs_imperialismus['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_globalisierung['vector'] = df_vecs_globalisierung['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_pluralismus['vector'] = df_vecs_pluralismus['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_klassenkampf['vector'] = df_vecs_klassenkampf['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_sozialstaat['vector'] = df_vecs_sozialstaat['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_revolutionäre['vector'] = df_vecs_revolutionäre['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_pazifismus['vector'] = df_vecs_pazifismus['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_anarchismus['vector'] = df_vecs_anarchismus['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_diskurs['vector'] = df_vecs_diskurs['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_konservatismus['vector'] = df_vecs_konservatismus['vector'].apply(lambda x: ast.literal_eval(x))

# %% [markdown]
# #### 1.3. Taking the mean() of every Word Vector per Year

# %%
df_mean_democracy = df_vecs_democracy.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_marktwirtschaft = df_vecs_marktwirtschaft.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_liberalismus= df_vecs_liberalismus.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_rechtsstaat = df_vecs_rechtsstaat.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_sozialismus = df_vecs_sozialismus.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_kapitalismus = df_vecs_kapitalismus.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_solidarität = df_vecs_solidarität.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_federalism =df_vecs_federalism.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_nationalismus = df_vecs_nationalismus.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_kommunismus =df_vecs_kommunismus.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_gerechtigkeit = df_vecs_gerechtigkeit.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_diktatur = df_vecs_diktatur.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_ideologie = df_vecs_ideologie.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_grundeinkommen = df_vecs_grundeinkommen.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_extremism =df_vecs_extremism.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_toleranz = df_vecs_toleranz.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_freedom = df_vecs_freedom.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_imperialismus = df_vecs_imperialismus.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_globalisierung = df_vecs_globalisierung.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_pluralismus = df_vecs_pluralismus.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_klassenkampf = df_vecs_klassenkampf.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_sozialstaat = df_vecs_sozialstaat.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_revolutionäre = df_vecs_revolutionäre.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_pazifismus = df_vecs_pazifismus.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_anarchismus = df_vecs_anarchismus.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_diskurs= df_vecs_diskurs.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_konservatismus = df_vecs_konservatismus.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()

# %% [markdown]
# #### 1.4. Merging the Data Frames grouped by the Year

# %%
def create_df_year(df):
    df_year = pd.DataFrame(columns=['year', 'word', 'vector'])
    for year, df_year_i in df.groupby('year'):
        df_year_i = df_year_i.groupby('word').agg({'vector': np.mean}).reset_index()
        df_year_i['year'] = year
        df_year = pd.concat([df_year, df_year_i], axis=0)
    return df_year

# %%
df_merged = pd.concat([df_mean_democracy, 
df_mean_marktwirtschaft, 
df_mean_liberalismus, 
df_mean_rechtsstaat,
df_mean_sozialismus, 
df_mean_kapitalismus, 
df_mean_solidarität, 
df_mean_federalism, 
df_mean_nationalismus,
df_mean_kommunismus,
df_mean_gerechtigkeit,
df_mean_diktatur,                       
df_mean_ideologie,
df_mean_grundeinkommen,
df_mean_extremism,
df_mean_toleranz,
df_mean_freedom,
df_mean_imperialismus,
df_mean_globalisierung,
df_mean_pluralismus,
df_mean_klassenkampf,
df_mean_sozialstaat,
df_mean_revolutionäre,
df_mean_pazifismus,
df_mean_anarchismus,
df_mean_diskurs,
df_mean_konservatismus], axis=0)
df_final_demokratie = df_merged.groupby('year').apply(create_df_year)

# %% [markdown]
# #### 1.5. Creating DataFrame: All WOI and their yearly Mean Vectors sorted by Year

# %%
df_final_demokratie
# Out:
#              year           word  \
# year
# 1946.0 0   1946.0     Demokratie
#        1   1946.0       Diktatur
#        2   1946.0        Diskurs
#        3   1946.0       Freiheit
#        4   1946.0  Gerechtigkeit
# ...           ...            ...
# 2014.0 21  2014.0    Solidarität
#        22  2014.0    Sozialismus
#        23  2014.0    Sozialstaat
#        24  2014.0       Toleranz
#        25  2014.0  revolutionäre
#
#                                                       vector
# year
# 1946.0 0   [-0.08169053138227635, -0.26886005798245177, -...
#        1   [-0.24700638457484866, -0.33328813800345297, 0...
#        2   [-0.47006772458553314, 0.34849323332309723, -0...
#        3   [-0.31260199078491757, -0.22046545417181082, -...
#        4   [0.17605411750929698, -0.2949231741683824, -0....
# ...                                                      ...
# 2014.0 21  [-0.18178770542144776, -0.3398026522587646, 0....
# ...

# %%
#save_df_final_demokratie = df_final_demokratie.to_csv("df_final_demokratie.csv", index=False)

# %% [markdown]
# ## 2. Data Calculation

# %% [markdown]
# ### 2.1. Calculating the Cosine Similarity

# %%
# Get a list of all unique words and years
unique_words = df_final_demokratie['word'].unique()
unique_years = df_final_demokratie['year'].unique()

cosine_similarities = {}
for year1 in unique_years:
    for word1 in unique_words:
        vector1 = df_final_demokratie.loc[(df_final_demokratie['word'] == word1) & (df_final_demokratie['year'] == year1), 'vector'].values
        if len(vector1) == 0:
            continue
        vector1 = vector1[0]
        for year2 in unique_years:
            for word2 in unique_words:
                vector2 = df_final_demokratie.loc[(df_final_demokratie['word'] == word2) & (df_final_demokratie['year'] == year2), 'vector'].values
                if len(vector2) == 0:
                    continue
                vector2 = vector2[0]
                dot_product = np.dot(vector1, vector2)
                magnitude_vector1 = np.linalg.norm(vector1)
                magnitude_vector2 = np.linalg.norm(vector2)
                cosine_similarity = dot_product / (magnitude_vector1 * magnitude_vector2)
                cosine_similarities[f"{word1}_{year1}_{word2}_{year2}"] = cosine_similarity

# %%
cosine_similarities = pd.DataFrame.from_dict(cosine_similarities, orient='index', columns=['cosine_similarity'])
cosine_similarities = cosine_similarities.reset_index()
cosine_similarities['word1'], cosine_similarities['year1'], cosine_similarities['word2'], cosine_similarities['year2'] = zip(*cosine_similarities['index'].str.split('_'))
cosine_similarities[['year1', 'year2']] = cosine_similarities[['year1', 'year2']].astype(float)

# %%
#save_df = cosine_similarities.to_csv('cosine_similarities_demokratie_all_w_all_y.csv', index=False)

# %%
cosine_similarities
# Out:
#                                                index  cosine_similarity  \
# 0                Demokratie_1946.0_Demokratie_1946.0           1.000000
# 1                  Demokratie_1946.0_Diktatur_1946.0           0.910958
# 2                   Demokratie_1946.0_Diskurs_1946.0           0.642744
# 3                  Demokratie_1946.0_Freiheit_1946.0           0.937814
# 4             Demokratie_1946.0_Gerechtigkeit_1946.0           0.923443
# ...                                              ...                ...
# 2505884     Grundeinkommen_2014.0_Extremismus_2014.0           0.666892
# 2505885     Grundeinkommen_2014.0_Sozialstaat_2014.0           0.723233
# 2505886     Grundeinkommen_2014.0_Pluralismus_2014.0           0.705567
# 2505887  Grundeinkommen_2014.0_Globalisierung_2014.0           0.641070
# 2505888  Grundeinkommen_2014.0_Grundeinkommen_2014.0           1.000000
#
#                   word1   year1           word2   year2
# ...

# %% [markdown]
# ## 2.2. Creating DataFrame: Comparing every word with "Demokratie"

# %%
df_same_years = cosine_similarities.loc[cosine_similarities['year1'] == cosine_similarities['year2']]

# %%
df_same_years_demokratie = df_same_years.loc[df_same_years['word1'] == 'Demokratie']

# %%
df_same_years_demokratie
# Out:
#                                            index  cosine_similarity  \
# 0            Demokratie_1946.0_Demokratie_1946.0           1.000000
# 1              Demokratie_1946.0_Diktatur_1946.0           0.910958
# 2               Demokratie_1946.0_Diskurs_1946.0           0.642744
# 3              Demokratie_1946.0_Freiheit_1946.0           0.937814
# 4         Demokratie_1946.0_Gerechtigkeit_1946.0           0.923443
# ...                                          ...                ...
# 2466309     Demokratie_2014.0_Extremismus_2014.0           0.810061
# 2466310     Demokratie_2014.0_Sozialstaat_2014.0           0.882645
# 2466311     Demokratie_2014.0_Pluralismus_2014.0           0.854950
# 2466312  Demokratie_2014.0_Globalisierung_2014.0           0.879220
# 2466313  Demokratie_2014.0_Grundeinkommen_2014.0           0.727494
#
#               word1   year1           word2   year2
# 0        Demokratie  1946.0      Demokratie  1946.0
# ...

# %% [markdown]
# ### 2.2.1. Visualization: Similarity Development between WOI and the word "Demokratie" over the years

# %%
custom_color_map = {
    'Anarchismus': '#5F56FC',
    'Demokratie': '#FF5733',
    'Diskurs': '#2ECC71',
    'Diktatur': '#E74C3C',
    'Extremismus': '#7F8C8D',
    'Föderalismus': '#1ABC9C',
    'Freiheit': '#FF00FF',
    'Gerechtigkeit': '#FFD700',
    'Globalisierung': '#34495E',
    'Grundeinkommen': '#3498DB',
    'Ideologie': '#E67E22',
    'Imperialismus': '#6F1E51',
    'Kapitalismus': '#E74C3C',
    'Klassenkampf': '#C0392B',
    'Kommunismus': '#84A59D',
    'Konservatismus': '#F1C40F',
    'Liberalismus': '#44B1CF',
    'Marktwirtschaft': '#DBDB8D',
    'Nationalismus': '#8E44AD',
    'Pazifismus': '#7EA310',
    'Pluralismus': '#8E44AD',
    'Rechtsstaat': '#E74C3C',
    'Solidarität': '#F39C12',
    'Sozialismus': '#E44C47',
    'Sozialstaat': '#E67E22',
    'Toleranz': '#FFA500',
    'revolutionäre': '#053F5C'
}

# %%
import plotly.express as px


fig = px.line(df_same_years_demokratie, x="year1", y="cosine_similarity", color="word2", color_discrete_map=custom_color_map, title = "Similarity Developement between Demokratie and WOI over the Years")
fig.update_yaxes(range=[0, 1])
#fig.show()

fig.write_html("cosine_similarity_demokratie_ld.html")

# %% [markdown]
# ### 2.2.2. Measuring the biggest Amplitude

# %%
import copy
df_same_years_demokratie_new = copy.deepcopy(df_same_years_demokratie)

# %%
df_same_years_demokratie_new_amplitude = df_same_years_demokratie_new.groupby(['word1', 'word2']).agg({'cosine_similarity': [min, max]})
df_same_years_demokratie_new_amplitude['amplitude'] = df_same_years_demokratie_new_amplitude['cosine_similarity']['max'] - df_same_years_demokratie_new_amplitude['cosine_similarity']['min']
df_same_years_demokratie_new_amplitude = df_same_years_demokratie_new_amplitude.reset_index()
result = df_same_years_demokratie_new_amplitude[df_same_years_demokratie_new_amplitude['amplitude'] == df_same_years_demokratie_new_amplitude['amplitude'].max()]
result
# Out:
#          word1     word2 cosine_similarity          amplitude
#                                        min      max
# 25  Demokratie  Toleranz          0.394563  0.92357  0.529007

# %% [markdown]
# ### 2.2.3. Measuring the Ascending Amplitude

# %%
df_same_years_demokratie_new_amplitude = df_same_years_demokratie_new_amplitude.sort_values("amplitude", ascending=False)
#inplace=True)
df_same_years_demokratie_new_amplitude
# Out:
#          word1            word2 cosine_similarity               amplitude
#                                               min       max
# 25  Demokratie         Toleranz          0.394563  0.923570  5.290069e-01
# 16  Demokratie     Liberalismus          0.411101  0.896744  4.856427e-01
# 26  Demokratie    revolutionäre          0.491358  0.921173  4.298159e-01
# 21  Demokratie      Rechtsstaat          0.531322  0.926020  3.946973e-01
# 19  Demokratie       Pazifismus          0.517712  0.888914  3.712018e-01
# 3   Demokratie          Diskurs          0.505842  0.862786  3.569440e-01
# 13  Demokratie     Klassenkampf          0.522473  0.876810  3.543369e-01
# 4   Demokratie      Extremismus          0.502743  0.856770  3.540271e-01
# 11  Demokratie    Imperialismus          0.532148  0.869239  3.370910e-01
# 15  Demokratie   Konservatismus          0.543427  0.880404  3.369772e-01
# 6   Demokratie     Föderalismus          0.565945  0.893402  3.274570e-01
# ...

# %% [markdown]
# #### 2.2.4. Visualization Developement over the years of: 3 biggest Aplitude and 3 lowest Amplitude

# %%
import plotly.express as px


# Filter dataframe to include only desired words
df_filtered = df_same_years_demokratie[df_same_years_demokratie["word1"].isin(["Demokratie"]) & df_same_years_demokratie["word2"].isin(["Freiheit", "Kommunismus", "Sozialismus", "revolutionäre", "Liberalismus", "Toleranz"])]

# Map each word to a different color and line shape
color_map = {"Freiheit": "#E74C3C", "Kommunismus": "#E74C3C", "Sozialismus": "#E74C3C", "revolutionäre": "#44B1CF", "Liberalismus": "#44B1CF", "Toleranz": "#44B1CF"}
line_shape_map = {"Freiheit": "solid", "Kommunismus": "dot", "Sozialismus": "dash", "revolutionäre": "solid", "Liberalismus": "dot", "Toleranz": "dash"}

# Create plot with desired colors and line shapes
fig = px.line(df_filtered, x="year1", y="cosine_similarity", color="word2", line_dash="word2", title="3 Biggest and 3 smallest Amplitude of Cosine Similarity", color_discrete_map=color_map, line_dash_map=line_shape_map)
fig.update_yaxes(range=[0, 1])

# Save plot to HTML file
fig.write_html("cosine_similarity_demokratie_ld_filtered.html")

# %% [markdown]
# ## 2.3. Creating DataFrame: Comparing every word with oneself over the years

# %% [markdown]
# ### 2.3.1. Repeating the steps from 1. Data Managing since the mean vectos have to be recalculated

# %% [markdown]
# ##### Creating a Dataframe with decade mean vectors first

# %%
import copy
df_vecs_democracy_copy = copy.deepcopy(df_vecs_democracy) 
df_vecs_marktwirtschaft_copy= copy.deepcopy(df_vecs_marktwirtschaft)
df_vecs_liberalismus_copy= copy.deepcopy(df_vecs_liberalismus)
df_vecs_rechtsstaat_copy= copy.deepcopy(df_vecs_rechtsstaat)
df_vecs_sozialismus_copy= copy.deepcopy(df_vecs_sozialismus)
df_vecs_kapitalismus_copy=copy.deepcopy(df_vecs_kapitalismus)
df_vecs_solidarität_copy=copy.deepcopy(df_vecs_solidarität)
df_vecs_federalism_copy=copy.deepcopy(df_vecs_federalism)
df_vecs_nationalismus_copy=copy.deepcopy(df_vecs_nationalismus)
df_vecs_kommunismus_copy=copy.deepcopy(df_vecs_kommunismus)
df_vecs_gerechtigkeit_copy=copy.deepcopy(df_vecs_gerechtigkeit)
df_vecs_diktatur_copy=copy.deepcopy(df_vecs_diktatur)
df_vecs_ideologie_copy=copy.deepcopy(df_vecs_ideologie)
df_vecs_grundeinkommen_copy=copy.deepcopy(df_vecs_grundeinkommen)
df_vecs_extremism_copy=copy.deepcopy(df_vecs_extremism)
df_vecs_toleranz_copy=copy.deepcopy(df_vecs_toleranz)
df_vecs_freedom_copy=copy.deepcopy(df_vecs_freedom)
df_vecs_imperialismus_copy=copy.deepcopy(df_vecs_imperialismus)
df_vecs_globalisierung_copy=copy.deepcopy(df_vecs_globalisierung)
df_vecs_pluralismus_copy=copy.deepcopy(df_vecs_pluralismus)
df_vecs_klassenkampf_copy=copy.deepcopy(df_vecs_klassenkampf)
df_vecs_sozialstaat_copy=copy.deepcopy(df_vecs_sozialstaat)
df_vecs_revolutionäre_copy=copy.deepcopy(df_vecs_revolutionäre)
df_vecs_pazifismus_copy=copy.deepcopy(df_vecs_pazifismus)
df_vecs_anarchismus_copy=copy.deepcopy(df_vecs_anarchismus)
df_vecs_diskurs_copy=copy.deepcopy(df_vecs_diskurs)
df_vecs_konservatismus_copy=copy.deepcopy(df_vecs_konservatismus)

# %%
# Create a dictionary mapping the year to the decade
def get_decade(year):
    if 1946 <= year <= 1955:
        return "1946-1955"
    elif 1956 <= year <= 1965:
        return "1956-1965"
    elif 1966 <= year <= 1975:
        return "1966-1975"
    elif 1976 <= year <= 1985:
        return "1976-1985"
    elif 1986 <= year <= 1995:
        return "1986-1995"
    elif 1996 <= year <= 2005:
        return "1996-2005"
    elif 2006 <= year <= 2014:
        return "2006-2014"
    else:
        return None

# %%
df_vecs_democracy_copy['decade'] = df_vecs_democracy_copy["year"].apply(lambda x: get_decade(x)) 
df_vecs_marktwirtschaft_copy['decade'] = df_vecs_marktwirtschaft_copy["year"].apply(lambda x: get_decade(x))
df_vecs_liberalismus_copy['decade'] = df_vecs_liberalismus_copy["year"].apply(lambda x: get_decade(x))
df_vecs_rechtsstaat_copy['decade'] = df_vecs_rechtsstaat_copy["year"].apply(lambda x: get_decade(x))
df_vecs_sozialismus_copy['decade'] = df_vecs_sozialismus_copy["year"].apply(lambda x: get_decade(x))
df_vecs_kapitalismus_copy['decade'] = df_vecs_kapitalismus_copy["year"].apply(lambda x: get_decade(x))
df_vecs_solidarität_copy['decade'] = df_vecs_solidarität_copy["year"].apply(lambda x: get_decade(x))
df_vecs_federalism_copy['decade'] = df_vecs_federalism_copy["year"].apply(lambda x: get_decade(x))
df_vecs_nationalismus_copy['decade'] = df_vecs_nationalismus_copy["year"].apply(lambda x: get_decade(x))
df_vecs_kommunismus_copy['decade'] = df_vecs_kommunismus_copy["year"].apply(lambda x: get_decade(x))
df_vecs_gerechtigkeit_copy['decade'] = df_vecs_gerechtigkeit_copy["year"].apply(lambda x: get_decade(x))
df_vecs_diktatur_copy['decade'] = df_vecs_diktatur_copy["year"].apply(lambda x: get_decade(x))
df_vecs_ideologie_copy['decade'] = df_vecs_ideologie_copy["year"].apply(lambda x: get_decade(x))
df_vecs_grundeinkommen_copy['decade'] = df_vecs_grundeinkommen_copy["year"].apply(lambda x: get_decade(x))
df_vecs_extremism_copy['decade'] = df_vecs_extremism_copy["year"].apply(lambda x: get_decade(x))
df_vecs_toleranz_copy['decade'] = df_vecs_toleranz_copy["year"].apply(lambda x: get_decade(x))
df_vecs_freedom_copy['decade'] = df_vecs_freedom_copy["year"].apply(lambda x: get_decade(x))
df_vecs_imperialismus_copy['decade'] = df_vecs_imperialismus_copy["year"].apply(lambda x: get_decade(x))
df_vecs_globalisierung_copy['decade'] = df_vecs_globalisierung_copy["year"].apply(lambda x: get_decade(x))
df_vecs_pluralismus_copy['decade'] = df_vecs_pluralismus_copy["year"].apply(lambda x: get_decade(x))
df_vecs_klassenkampf_copy['decade'] = df_vecs_klassenkampf_copy["year"].apply(lambda x: get_decade(x))
df_vecs_sozialstaat_copy['decade'] = df_vecs_sozialstaat_copy["year"].apply(lambda x: get_decade(x))
df_vecs_revolutionäre_copy['decade'] = df_vecs_revolutionäre_copy["year"].apply(lambda x: get_decade(x))
df_vecs_pazifismus_copy['decade'] = df_vecs_pazifismus_copy["year"].apply(lambda x: get_decade(x))
df_vecs_anarchismus_copy['decade'] = df_vecs_anarchismus_copy["year"].apply(lambda x: get_decade(x))
df_vecs_diskurs_copy['decade'] = df_vecs_diskurs_copy["year"].apply(lambda x: get_decade(x))
df_vecs_konservatismus_copy['decade'] = df_vecs_konservatismus_copy["year"].apply(lambda x: get_decade(x))

# %%
df_mean_demokratie_decade = df_vecs_democracy_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index() 
df_mean_marktwirtschaft_decade = df_vecs_marktwirtschaft_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_liberalismus_decade = df_vecs_liberalismus_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_rechtsstaat_decade = df_vecs_rechtsstaat_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_sozialismus_decade = df_vecs_sozialismus_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_kapitalismus_decade = df_vecs_kapitalismus_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_solidarität_decade = df_vecs_solidarität_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_federalism_decade = df_vecs_federalism_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_nationalismus_decade = df_vecs_nationalismus_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_kommunismus_deacde = df_vecs_kommunismus_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_gerechtigkeit_deacde = df_vecs_gerechtigkeit_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_diktatur_decade = df_vecs_diktatur_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_ideologie_decade = df_vecs_ideologie_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_grundeinkommen_decade = df_vecs_grundeinkommen_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_extremism_decade = df_vecs_extremism_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_toleranz_decade = df_vecs_toleranz_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_freedom_decade = df_vecs_freedom_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_imperialismus_decade = df_vecs_imperialismus_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_globalisierung_decade = df_vecs_globalisierung_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_pluralismus_decade = df_vecs_pluralismus_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_klassenkampf_decade = df_vecs_klassenkampf_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_sozialstaat_decade = df_vecs_sozialstaat_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_revolutionäre_decade = df_vecs_revolutionäre_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_pazifismus_decade = df_vecs_pazifismus_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_anarchismus_decade = df_vecs_anarchismus_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_diskurs_decade = df_vecs_diskurs_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_konservatismus_decade = df_vecs_konservatismus_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()

# %%
df_mean_decade_concat = pd.concat([df_mean_demokratie_decade,
df_mean_marktwirtschaft_decade,
df_mean_liberalismus_decade,
df_mean_rechtsstaat_decade,
df_mean_sozialismus_decade,
df_mean_kapitalismus_decade,
df_mean_solidarität_decade,
df_mean_federalism_decade,
df_mean_nationalismus_decade,
df_mean_kommunismus_deacde,
df_mean_gerechtigkeit_deacde,
df_mean_diktatur_decade,
df_mean_ideologie_decade,
df_mean_grundeinkommen_decade,
df_mean_extremism_decade,
df_mean_toleranz_decade,
df_mean_freedom_decade,
df_mean_imperialismus_decade,
df_mean_globalisierung_decade,
df_mean_klassenkampf_decade,
df_mean_sozialstaat_decade,
df_mean_revolutionäre_decade,
df_mean_pazifismus_decade,
df_mean_anarchismus_decade,
df_mean_diskurs_decade,
df_mean_konservatismus_decade], axis=0)

# %%
def create_df_decade(df):
    df_year = pd.DataFrame(columns=['decade', 'word', 'vector'])
    for year, df_year_i in df.groupby('decade'):
        df_year_i = df_year_i.groupby('word').agg({'vector': np.mean}).reset_index()
        df_year_i['decade'] = year
        df_year = pd.concat([df_year, df_year_i], axis=0)
    return df_year

# %%
df_mean_decade = df_mean_decade_concat.groupby('decade').apply(create_df_decade)

# %%
#df_mean_decade.head()
#save_df = df_mean_decade.to_csv('df_mean_decade_demokratie.csv', index=False)

# %% [markdown]
# ### 2.3.2. Cosine Similarity: calculating mean vectors for decades

# %%
# Get a list of all unique words
unique_words = df_mean_decade['word'].unique()

# Get a list of all unique decades
unique_decades = df_mean_decade['decade'].unique()

cosine_similarities_decade = {}
for i, decade1 in enumerate(unique_decades):
    for word1 in unique_words:
        vector1 = df_mean_decade.loc[(df_mean_decade['word'] == word1) & (df_mean_decade['decade'] == decade1), 'vector'].values
        if len(vector1) == 0:
            continue
        vector1 = vector1[0]
        for j, decade2 in enumerate(unique_decades[i+1:]):
           #  Check if the difference between the decades is equal to 10
            if int(decade2[:4]) - int(decade1[:4]) != 10:
                continue
            for word2 in unique_words:
                vector2 = df_mean_decade.loc[(df_mean_decade['word'] == word2) & (df_mean_decade['decade'] == decade2), 'vector'].values
                if len(vector2) == 0:
                    continue
                vector2 = vector2[0]
                dot_product = np.dot(vector1, vector2)
                magnitude_vector1 = np.linalg.norm(vector1)
                magnitude_vector2 = np.linalg.norm(vector2)
                cosine_similarity = dot_product / (magnitude_vector1 * magnitude_vector2)
                cosine_similarities_decade[f"{word1}_{decade1}_{word2}_{decade2}"] = cosine_similarity
cosine_similarities_decade = pd.DataFrame.from_dict(cosine_similarities_decade, orient='index', columns=['cosine_similarity'])
cosine_similarities_decade = cosine_similarities_decade.reset_index()
cosine_similarities_decade['word1'], cosine_similarities_decade['decade1'], cosine_similarities_decade['word2'], cosine_similarities_decade['decade2'] = zip(*cosine_similarities_decade['index'].str.split('_'))
cosine_similarities_decade[['decade1', 'decade2']] = cosine_similarities_decade[['decade1', 'decade2']].astype(str)

# %%
cosine_similarities_decade
# Out:
#                                                   index  cosine_similarity  \
# 0           Anarchismus_1946-1955_Anarchismus_1956-1965           0.827832
# 1            Anarchismus_1946-1955_Demokratie_1956-1965           0.660230
# 2              Anarchismus_1946-1955_Diktatur_1956-1965           0.676553
# 3           Anarchismus_1946-1955_Extremismus_1956-1965           0.725998
# 4              Anarchismus_1946-1955_Freiheit_1956-1965           0.633582
# ...                                                 ...                ...
# 3625        Grundeinkommen_1996-2005_Toleranz_2006-2014           0.700057
# 3626   Grundeinkommen_1996-2005_revolutionäre_2006-2014           0.700715
# 3627     Grundeinkommen_1996-2005_Sozialstaat_2006-2014           0.714500
# 3628  Grundeinkommen_1996-2005_Globalisierung_2006-2014           0.607005
# 3629  Grundeinkommen_1996-2005_Grundeinkommen_2006-2014           0.804768
#
#                word1    decade1           word2    decade2
# ...

# %% [markdown]
# ### 2.3.3. Creating Word2Word DataFrame with only Cosine Similarities to ONESELF

# %%
# Filter the rows where the word1 and word2 are the same and decade1 is consecutive to decade2
df = cosine_similarities_decade[(cosine_similarities_decade["word1"] == cosine_similarities_decade["word2"]) & (cosine_similarities_decade["decade1"] == cosine_similarities_decade["decade1"])]

# Reset the index of the filtered dataframe
#df = df.reset_index(drop=True)

# Print the filtered dataframe
df
# Out:
#                                                   index  cosine_similarity  \
# 0           Anarchismus_1946-1955_Anarchismus_1956-1965           0.827832
# 24            Demokratie_1946-1955_Demokratie_1956-1965           0.990741
# 48                Diktatur_1946-1955_Diktatur_1956-1965           0.994434
# 95          Extremismus_1946-1955_Extremismus_1956-1965           0.907590
# 119               Freiheit_1946-1955_Freiheit_1956-1965           0.998047
# ...                                                 ...                ...
# 3521              Toleranz_1996-2005_Toleranz_2006-2014           0.994339
# 3548    revolutionäre_1996-2005_revolutionäre_2006-2014           0.984219
# 3575        Sozialstaat_1996-2005_Sozialstaat_2006-2014           0.995588
# 3602  Globalisierung_1996-2005_Globalisierung_2006-2014           0.997626
# 3629  Grundeinkommen_1996-2005_Grundeinkommen_2006-2014           0.804768
#
#                word1    decade1           word2    decade2
# ...

# %%
df["x_axis_label"] = df["decade2"].apply(lambda x: "bis "+str(int(x[-4:])-1) if x == "1946-1955" else x)
df["x_axis_label"] = df["x_axis_label"].apply(lambda x: "bis "+str(int(x[-4:])+1) if x == "1956-1965" else x)
df["x_axis_label"] = df["x_axis_label"].apply(lambda x: "bis "+str(int(x[-4:])+1) if x == "1966-1975" else x)
df["x_axis_label"] = df["x_axis_label"].apply(lambda x: "bis "+str(int(x[-4:])+1) if x == "1976-1985" else x)
df["x_axis_label"] = df["x_axis_label"].apply(lambda x: "bis "+str(int(x[-4:])+1) if x == "1986-1995" else x)
df["x_axis_label"] = df["x_axis_label"].apply(lambda x: "bis "+str(int(x[-4:])+1) if x == "1996-2005" else x)
df["x_axis_label"] = df["x_axis_label"].apply(lambda x: "bis "+str(int(x[-4:])+1) if x == "2006-2014" else x)
# Out:
# /tmp/ipykernel_7020/3322918344.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_7020/3322918344.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_7020/3322918344.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# <b>!For scientific corecctness we have to eluminate words out of hte calculation, which are not represented in every consecutive decade!</b>

# %%
to_eliminate = ['Diskurs', 'Pluralismus', 'Globalisierung', 'Grundeinkommen']
df = df[~df['word1'].isin(to_eliminate)]

# %%
df
# Out:
#                                                 index  cosine_similarity  \
# 0         Anarchismus_1946-1955_Anarchismus_1956-1965           0.827832
# 24          Demokratie_1946-1955_Demokratie_1956-1965           0.990741
# 48              Diktatur_1946-1955_Diktatur_1956-1965           0.994434
# 95        Extremismus_1946-1955_Extremismus_1956-1965           0.907590
# 119             Freiheit_1946-1955_Freiheit_1956-1965           0.998047
# ...                                               ...                ...
# 3467      Solidarität_1996-2005_Solidarität_2006-2014           0.993268
# 3494      Sozialismus_1996-2005_Sozialismus_2006-2014           0.995442
# 3521            Toleranz_1996-2005_Toleranz_2006-2014           0.994339
# 3548  revolutionäre_1996-2005_revolutionäre_2006-2014           0.984219
# 3575      Sozialstaat_1996-2005_Sozialstaat_2006-2014           0.995588
#
#               word1    decade1          word2    decade2 x_axis_label
# ...

# %%
quantile_5 = df["cosine_similarity"].quantile(0.05)

# %%
quantile_5
# Out:
# 0.9018827877533439

# %%
df.loc[df["cosine_similarity"] <= quantile_5 ]["word2"].unique()
# Out:
# array(['Anarchismus', 'Konservatismus', 'Sozialstaat'], dtype=object)

# %% [markdown]
# <br>

# %% [markdown]
# ## 2.3.4. Visualization: Similarity Development between WOI to Themselfes over the Years

# %%
import plotly.express as px


fig_d = px.line(df, x='x_axis_label', y='cosine_similarity', color='word2', color_discrete_map=custom_color_map, title = "Similarity Developement of WOI to Oneself over Decades")
fig_d.update_yaxes(range=[0, 1])
fig_d.update_layout(title={'text': "Similarity Developement of WOI to Oneself over Decades", 'y':0.95,'x':0.5,'xanchor': 'right','yanchor': 'top'})
fig_d.add_shape(
    type = 'line',
    y0=quantile_5,
    y1=quantile_5,
    x0=df['x_axis_label'].min(),
    x1=df['x_axis_label'].max(),
    yref='paper',
    xref='x',
    line=dict(color='gray', dash='dash')
)
fig_d.add_annotation(
    x='bis 2006',
    y=quantile_5,
    text=f'5% quantile: {quantile_5:.5f}',
    xref='x',
    yref='y',
    showarrow=False,
    font=dict(color='gray'))
    #fig.show()
fig_d.write_html("cosine_similarity_demokratie_word2word_decade.html")
