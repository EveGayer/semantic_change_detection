# %% [markdown]
# # Processing Vectors for Analysis (out of many Dataframe)
# ### Umwelt

# %% [markdown]
# - Loading the Data
# - Creating a Dataframe with every WOI and its yearly mean vectors
# - Creating a similarity matrix for WOI to the TARGET WORD and its visualization
# - Creating a Dataframe with every WOI and its decade mean vectors
# - Creating a similarity matrix with decade mean vectors for WOI to the oneself and its visualization

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Data Managing

# %% [markdown]
# ##### 1.1. Loading the Data Frames

# %%
df_vecs_umwelt = pd.read_csv("df_umwelt/df_vecs_umwelt.csv")
df_vecs_umweltschutz = pd.read_csv("df_umwelt/df_vecs_umweltschutz.csv")
df_vecs_klimaschutz = pd.read_csv("df_umwelt/df_vecs_klimaschutz.csv")
df_vecs_naturschutz = pd.read_csv("df_umwelt/df_vecs_naturschutz.csv")
df_vecs_gesundheit = pd.read_csv("df_umwelt/df_vecs_gesundheit.csv")
df_vecs_nachhaltigkeit = pd.read_csv("df_umwelt/df_vecs_nachhaltigkeit.csv")
df_vecs_klimawandel = pd.read_csv("df_umwelt/df_vecs_klimawandel.csv")
df_vecs_natur = pd.read_csv("df_umwelt/df_vecs_natur.csv")
df_vecs_raumordnung =pd.read_csv("df_umwelt/df_vecs_raumordnung.csv")
df_vecs_umweltpolitik = pd.read_csv("df_umwelt/df_vecs_umweltpolitik.csv")
df_vecs_arbeitsschutz =pd.read_csv("df_umwelt/df_vecs_arbeitsschutz.csv")
df_vecs_energiewende = pd.read_csv("df_umwelt/df_vecs_energiewende.csv")
df_vecs_energiepolitik = pd.read_csv("df_umwelt/df_vecs_energiepolitik.csv")
df_vecs_ökologische = pd.read_csv("df_umwelt/df_vecs_ökologische.csv")
df_vecs_soziales =pd.read_csv("df_umwelt/df_vecs_soziales.csv")
df_vecs_tierschutz = pd.read_csv("df_umwelt/df_vecs_tierschutz.csv")
df_vecs_umweltbundesamt = pd.read_csv("df_umwelt/df_vecs_umweltbundesamt.csv")
df_vecs_mobilität = pd.read_csv("df_umwelt/df_vecs_mobilität.csv")
df_vecs_gewässerschutz = pd.read_csv("df_umwelt/df_vecs_gewässerschutz.csv")
df_vecs_raumplanung = pd.read_csv("df_umwelt/df_vecs_raumplanung.csv")
df_vecs_agrar = pd.read_csv("df_umwelt/df_vecs_agrar.csv")
df_vecs_landnutzung = pd.read_csv("df_umwelt/df_vecs_landnutzung.csv")
df_vecs_umweltfragen = pd.read_csv("df_umwelt/df_vecs_umweltfragen.csv")
df_vecs_datenschutz = pd.read_csv("df_umwelt/df_vecs_datenschutz.csv")
df_vecs_bodenschutz = pd.read_csv("df_umwelt/df_vecs_bodenschutz.csv")
df_vecs_ressourcen = pd.read_csv("df_umwelt/df_vecs_ressourcen.csv")
df_vecs_digitalisierung = pd.read_csv("df_umwelt/df_vecs_digitalisierung.csv")

# %%
#converting rows into right spelling for it not caring any contextual value and just beeing misspeled
df_vecs_agrar.loc[df_vecs_agrar["word"] == "agrar", "word"] = "Agrar"
df_vecs_agrar.loc[df_vecs_agrar["word"] == "AGRAR", "word"] = "Agrar"
df_vecs_soziales.loc[df_vecs_soziales["word"] == "Soziales", "word"] = "soziales"

# %% [markdown]
# #### 1.2. Converting the list of vectors to a float

# %%
import ast

df_vecs_umwelt['vector'] = df_vecs_umwelt['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_umweltschutz['vector'] = df_vecs_umweltschutz['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_klimaschutz['vector'] = df_vecs_klimaschutz['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_naturschutz['vector'] = df_vecs_naturschutz['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_gesundheit['vector'] = df_vecs_gesundheit['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_nachhaltigkeit['vector'] = df_vecs_nachhaltigkeit['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_klimawandel['vector'] = df_vecs_klimawandel['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_natur['vector'] = df_vecs_natur['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_raumordnung['vector'] = df_vecs_raumordnung['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_umweltpolitik['vector'] = df_vecs_umweltpolitik['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_arbeitsschutz['vector'] = df_vecs_arbeitsschutz['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_energiewende['vector'] = df_vecs_energiewende['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_energiepolitik['vector'] = df_vecs_energiepolitik['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_ökologische['vector'] = df_vecs_ökologische['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_soziales['vector'] = df_vecs_soziales['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_tierschutz['vector'] = df_vecs_tierschutz['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_umweltbundesamt['vector'] = df_vecs_umweltbundesamt['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_mobilität['vector'] = df_vecs_mobilität['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_gewässerschutz['vector'] = df_vecs_gewässerschutz['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_raumplanung['vector'] = df_vecs_raumplanung['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_agrar['vector'] = df_vecs_agrar['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_landnutzung['vector'] = df_vecs_landnutzung['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_umweltfragen['vector'] = df_vecs_umweltfragen['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_datenschutz['vector'] = df_vecs_datenschutz['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_bodenschutz['vector'] = df_vecs_bodenschutz['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_ressourcen['vector'] = df_vecs_ressourcen['vector'].apply(lambda x: ast.literal_eval(x))
df_vecs_digitalisierung['vector'] = df_vecs_digitalisierung['vector'].apply(lambda x: ast.literal_eval(x))

# %% [markdown]
# #### 1.3. Taking the mean() of every Word Vector per Year

# %%
df_mean_umwelt = df_vecs_umwelt.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_umweltschutz = df_vecs_umweltschutz.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_klimaschutz= df_vecs_klimaschutz.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_naturschutz = df_vecs_naturschutz.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_gesundheit = df_vecs_gesundheit.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_nachhaltigkeit = df_vecs_nachhaltigkeit.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_klimawandel = df_vecs_klimawandel.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_natur = df_vecs_natur.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_raumordnung =df_vecs_raumordnung.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_umweltpolitik = df_vecs_umweltpolitik.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_arbeitsschutz =df_vecs_arbeitsschutz.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_energiewende = df_vecs_energiewende.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_energiepolitik = df_vecs_energiepolitik.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_ökologische = df_vecs_ökologische.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_soziales =df_vecs_soziales.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_tierschutz = df_vecs_tierschutz.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_umweltbundesamt = df_vecs_umweltbundesamt.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_mobilität = df_vecs_mobilität.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_gewässerschutz = df_vecs_gewässerschutz.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_raumplanung = df_vecs_raumplanung.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_agrar = df_vecs_agrar.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_landnutzung = df_vecs_landnutzung.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_umweltfragen = df_vecs_umweltfragen.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_datenschutz = df_vecs_datenschutz.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_bodenschutz = df_vecs_bodenschutz.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_ressourcen= df_vecs_ressourcen.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_digitalisierung = df_vecs_digitalisierung.groupby('year').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()

# %% [markdown]
# #### 1.4. Merging the Data Frames grouped by the Year

# %%
def create_df_year(df):
    df_year = pd.DataFrame(columns=['year', 'word', 'vector'])
    for year, df_year_i in df.groupby('year'):
        df_year_i = df_year_i.groupby('word').agg({'vector': np.mean}).reset_index()
        df_year_i['year'] = year
        df_year = pd.concat([df_year, df_year_i], axis=0)
    return df_year

# %%
df_merged = pd.concat([df_mean_umwelt,
df_mean_umweltschutz,
df_mean_klimaschutz,
df_mean_naturschutz,
df_mean_gesundheit,
df_mean_nachhaltigkeit,
df_mean_klimawandel,
df_mean_natur,                       
df_mean_raumordnung,
df_mean_umweltpolitik,
df_mean_arbeitsschutz,
df_mean_energiewende,
df_mean_energiepolitik,
df_mean_ökologische,
df_mean_soziales,
df_mean_tierschutz,
df_mean_umweltbundesamt,
df_mean_mobilität,
df_mean_gewässerschutz,
df_mean_raumplanung,
df_mean_agrar,
df_mean_landnutzung,
df_mean_umweltfragen,
df_mean_datenschutz,
df_mean_bodenschutz,
df_mean_ressourcen,
df_mean_digitalisierung], axis=0)
df_final_umwelt = df_merged.groupby('year').apply(create_df_year)

# %% [markdown]
# #### 1.5. Creating DataFrame: All WOI and their yearly Mean Vectors sorted by Year

# %%
df_final_umwelt
# Out:
#              year           word  \
# year
# 1946.0 0   1946.0          Agrar
#        1   1946.0     Gesundheit
#        2   1946.0          Natur
#        3   1946.0         Umwelt
# 1947.0 0   1947.0          Agrar
# ...           ...            ...
# 2014.0 18  2014.0   Umweltfragen
#        19  2014.0  Umweltpolitik
#        20  2014.0   Umweltschutz
#        21  2014.0       soziales
#        22  2014.0    ökologische
#
#                                                       vector
# year
# 1946.0 0   [0.37059702910482883, -0.45912948064506054, 0....
#        1   [0.30049153908409854, -0.18789794905619187, -0...
#        2   [-0.10050232837975814, 0.10421409070590473, -0...
#        3   [-0.10324840229004621, -0.1012135859578848, 0....
# 1947.0 0   [0.9357970952987671, -0.6046255230903625, 0.33...
# ...                                                      ...
# 2014.0 18  [0.6323682069778442, -0.703255832195282, 0.302...
# ...

# %%
#save_df_final_umwelt = df_final_umwelt.to_csv("df_final_umwelt.csv", index=False)

# %% [markdown]
# <br>

# %% [markdown]
# ## 2. Data Calculation

# %% [markdown]
# ### 2.1. Calculating the Cosine Similarity

# %%
# Get a list of all unique words and years
unique_words = df_final_umwelt['word'].unique()
unique_years = df_final_umwelt['year'].unique()

cosine_similarities = {}
for year1 in unique_years:
    for word1 in unique_words:
        vector1 = df_final_umwelt.loc[(df_final_umwelt['word'] == word1) & (df_final_umwelt['year'] == year1), 'vector'].values
        if len(vector1) == 0:
            continue
        vector1 = vector1[0]
        for year2 in unique_years:
            for word2 in unique_words:
                vector2 = df_final_umwelt.loc[(df_final_umwelt['word'] == word2) & (df_final_umwelt['year'] == year2), 'vector'].values
                if len(vector2) == 0:
                    continue
                vector2 = vector2[0]
                dot_product = np.dot(vector1, vector2)
                magnitude_vector1 = np.linalg.norm(vector1)
                magnitude_vector2 = np.linalg.norm(vector2)
                cosine_similarity = dot_product / (magnitude_vector1 * magnitude_vector2)
                cosine_similarities[f"{word1}_{year1}_{word2}_{year2}"] = cosine_similarity

# %%
cosine_similarities = pd.DataFrame.from_dict(cosine_similarities, orient='index', columns=['cosine_similarity'])
cosine_similarities = cosine_similarities.reset_index()
cosine_similarities['word1'], cosine_similarities['year1'], cosine_similarities['word2'], cosine_similarities['year2'] = zip(*cosine_similarities['index'].str.split('_'))
cosine_similarities[['year1', 'year2']] = cosine_similarities[['year1', 'year2']].astype(float)

# %%
cosine_similarities
# Out:
#                                              index  cosine_similarity  \
# 0                        Agrar_1946.0_Agrar_1946.0           1.000000
# 1                   Agrar_1946.0_Gesundheit_1946.0           0.751950
# 2                        Agrar_1946.0_Natur_1946.0           0.861721
# 3                       Agrar_1946.0_Umwelt_1946.0           0.820100
# 4                        Agrar_1946.0_Agrar_1947.0           0.842255
# ...                                            ...                ...
# 802811  Energiewende_2014.0_Umweltbundesamt_2014.0           0.599109
# 802812      Energiewende_2014.0_Klimaschutz_2014.0           0.840699
# 802813   Energiewende_2014.0_Nachhaltigkeit_2014.0           0.849440
# 802814  Energiewende_2014.0_Digitalisierung_2014.0           0.853207
# 802815     Energiewende_2014.0_Energiewende_2014.0           1.000000
#
#                word1   year1            word2   year2
# 0              Agrar  1946.0            Agrar  1946.0
# ...

# %%
#save_df = cosine_similarities.to_csv('cosine_similarities_umwelt_all_w_all_y.csv', index=False)

# %% [markdown]
# ## 2.2. Creating DataFrame: Comparing every word with "Umwelt"

# %%
df_same_years = cosine_similarities.loc[cosine_similarities['year1'] == cosine_similarities['year2']]

# %%
df_same_years_umwelt = df_same_years.loc[df_same_years['word1'] == 'Umwelt']

# %%
df_same_years_umwelt
# Out:
#                                        index  cosine_similarity   word1  \
# 2688              Umwelt_1946.0_Agrar_1946.0           0.820100  Umwelt
# 2689         Umwelt_1946.0_Gesundheit_1946.0           0.852081  Umwelt
# 2690              Umwelt_1946.0_Natur_1946.0           0.921970  Umwelt
# 2691             Umwelt_1946.0_Umwelt_1946.0           1.000000  Umwelt
# 6276              Umwelt_1947.0_Agrar_1947.0           0.697635  Umwelt
# ...                                      ...                ...     ...
# 785787  Umwelt_2014.0_Umweltbundesamt_2014.0           0.599711  Umwelt
# 785788      Umwelt_2014.0_Klimaschutz_2014.0           0.862302  Umwelt
# 785789   Umwelt_2014.0_Nachhaltigkeit_2014.0           0.862099  Umwelt
# 785790  Umwelt_2014.0_Digitalisierung_2014.0           0.790110  Umwelt
# 785791     Umwelt_2014.0_Energiewende_2014.0           0.878109  Umwelt
#
#          year1            word2   year2
# 2688    1946.0            Agrar  1946.0
# ...

# %% [markdown]
# ### 2.2.1. Visualization: Similarity Development between WOI and the word "Umwelt" over the years

# %%
custom_color_map = {
    'Agrar': '#00FF00',
    'Arbeitsschutz': '#E67E22',
    'Bodenschutz': '#FF69B4',
    'Datenschutz': '#8E44AD',
    'Digitalisierung': '#1ABC9C',
    'Energiepolitik': '#FFD700',
    'Energiewende': '#FF00FF',
    'Gesundheit': '#E74C3C',
    'Gewässerschutz': '#F39C12',
    'Klimaschutz': '#44B1CF',
    'Klimawandel': '#053F5C',
    'Landnutzung': '#8B4513',
    'Mobilität': '#FF5733',
    'Nachhaltigkeit': '#5F56FC',
    'Naturschutz': '#D3AFCD',
    'Natur': '#228B22',
    'ökologische': '#F1C40F',
    'Raumordnung': '#6F1E51',
    'Raumplanung': '#E74C3C',
    'Ressourcen': '#3498DB',
    'soziales': '#FFC300',
    'Tierschutz': '#9400D3',
    'Umwelt': '#2ECC40',
    'Umweltpolitik': '#FF5733',
    'Umweltbundesamt': '#7F8C8D',
    'Umweltfragen': '#339900',
    'Umweltschutz': '#16A085'
}

# %%
import plotly.express as px


fig = px.line(df_same_years_umwelt, x="year1", y="cosine_similarity", color="word2", color_discrete_map=custom_color_map, title = "Similarity Developement between Umwelt and WOI over the Years")
fig.update_yaxes(range=[0, 1])
#fig.show()

fig.write_html("cosine_similarity_umwelt_ld_all_words.html")

# %% [markdown]
# ### 2.2.2. Measuring the biggest Amplitude

# %%
import copy
df_same_years_umwelt_new = copy.deepcopy(df_same_years_umwelt)

# %%
df_same_years_umwelt_new_amplitude = df_same_years_umwelt_new.groupby(['word1', 'word2']).agg({'cosine_similarity': [min, max]})
df_same_years_umwelt_new_amplitude['amplitude'] = df_same_years_umwelt_new_amplitude['cosine_similarity']['max'] - df_same_years_umwelt_new_amplitude['cosine_similarity']['min']
df_same_years_umwelt_new_amplitude = df_same_years_umwelt_new_amplitude.reset_index()
result = df_same_years_umwelt_new_amplitude[df_same_years_umwelt_new_amplitude['amplitude'] == df_same_years_umwelt_new_amplitude['amplitude'].max()]
result
# Out:
#      word1        word2 cosine_similarity          amplitude
#                                       min      max
# 15  Umwelt  Naturschutz          0.411299  0.86049  0.449191

# %% [markdown]
# ### 2.2.3. Measuring the Ascending Amplitude

# %%
df_same_years_umwelt_new_amplitude = df_same_years_umwelt_new_amplitude.sort_values("amplitude", ascending=False)
#inplace=True)
df_same_years_umwelt_new_amplitude
# Out:
#      word1            word2 cosine_similarity               amplitude
#                                           min       max
# 15  Umwelt      Naturschutz          0.411299  0.860490  4.491914e-01
# 25  Umwelt         soziales          0.442668  0.881669  4.390016e-01
# 0   Umwelt            Agrar          0.464483  0.880903  4.164192e-01
# 26  Umwelt      ökologische          0.513358  0.922123  4.087648e-01
# 5   Umwelt   Energiepolitik          0.526977  0.926926  3.999494e-01
# 19  Umwelt       Tierschutz          0.522998  0.904674  3.816765e-01
# 16  Umwelt      Raumordnung          0.455687  0.833857  3.781703e-01
# 3   Umwelt      Datenschutz          0.546158  0.911138  3.649803e-01
# 1   Umwelt    Arbeitsschutz          0.349692  0.704248  3.545565e-01
# 17  Umwelt      Raumplanung          0.545634  0.882424  3.367906e-01
# 12  Umwelt        Mobilität          0.594484  0.923085  3.286011e-01
# 7   Umwelt       Gesundheit          0.646010  0.969570  3.235603e-01
# ...

# %% [markdown]
# #### 2.2.4. Visualization Developement over the years of: 3 biggest Aplitude and 3 lowest Amplitude

# %%
import plotly.express as px


# Filter dataframe to include only desired words
df_filtered = df_same_years_umwelt[df_same_years_umwelt["word1"].isin(["Umwelt"]) & df_same_years_umwelt["word2"].isin(["Bodenschutz", "Landnutzung", "Natur", "Agrar", "soziales", "Naturschutz"])]

# Map each word to a different color and line shape
color_map = {"Bodenschutz": "#FF5733", "Landnutzung": "#FF5733", "Natur": "#FF5733", "Agrar": "#2ECC40", "soziales": "#2ECC40", "Naturschutz": "#2ECC40"}
line_shape_map = {"Bodenschutz": "solid", "Landnutzung": "dot", "Natur": "dash", "Agrar": "solid", "soziales": "dot", "Naturschutz": "dash"}

# Create plot with desired colors and line shapes
fig = px.line(df_filtered, x="year1", y="cosine_similarity", color="word2", line_dash="word2", title="3 Biggest and 3 smallest Amplitude of Cosine Similarity", color_discrete_map=color_map, line_dash_map=line_shape_map)
fig.update_yaxes(range=[0, 1])

# Save plot to HTML file
fig.write_html("cosine_similarity_umwelt_ld_filtered.html")

# %% [markdown]
# ## 2.3. Creating DataFrame: Comparing every word with oneself over the years

# %% [markdown]
# ### 2.3.1. Repeating the steps from 1. Data Managing since the mean vectos have to be recalculated

# %% [markdown]
# ##### Creating a Dataframe with decade mean vectors first

# %%
#making a copy of the original variables
import copy
df_vecs_umwelt_copy = copy.deepcopy(df_vecs_umwelt)
df_vecs_umweltschutz_copy = copy.deepcopy(df_vecs_umweltschutz) 
df_vecs_klimaschutz_copy = copy.deepcopy(df_vecs_klimaschutz) 
df_vecs_naturschutz_copy = copy.deepcopy(df_vecs_naturschutz) 
df_vecs_gesundheit_copy = copy.deepcopy(df_vecs_gesundheit)
df_vecs_nachhaltigkeit_copy = copy.deepcopy(df_vecs_nachhaltigkeit) 
df_vecs_klimawandel_copy = copy.deepcopy(df_vecs_klimawandel)
df_vecs_natur_copy = copy.deepcopy(df_vecs_natur)
df_vecs_raumordnung_copy = copy.deepcopy(df_vecs_raumordnung) 
df_vecs_umweltpolitik_copy = copy.deepcopy(df_vecs_umweltpolitik) 
df_vecs_arbeitsschutz_copy = copy.deepcopy(df_vecs_arbeitsschutz)
df_vecs_energiewende_copy = copy.deepcopy(df_vecs_energiewende)
df_vecs_energiepolitik_copy = copy.deepcopy(df_vecs_energiepolitik)
df_vecs_ökologische_copy = copy.deepcopy(df_vecs_ökologische)
df_vecs_soziales_copy = copy.deepcopy(df_vecs_soziales)
df_vecs_tierschutz_copy = copy.deepcopy(df_vecs_tierschutz) 
df_vecs_umweltbundesamt_copy = copy.deepcopy(df_vecs_umweltbundesamt) 
df_vecs_mobilität_copy = copy.deepcopy(df_vecs_mobilität) 
df_vecs_gewässerschutz_copy = copy.deepcopy(df_vecs_gewässerschutz)
df_vecs_raumplanung_copy = copy.deepcopy(df_vecs_raumplanung) 
df_vecs_agrar_copy = copy.deepcopy(df_vecs_agrar)
df_vecs_landnutzung_copy = copy.deepcopy(df_vecs_landnutzung) 
df_vecs_umweltfragen_copy = copy.deepcopy(df_vecs_umweltfragen) 
df_vecs_datenschutz_copy = copy.deepcopy(df_vecs_datenschutz) 
df_vecs_bodenschutz_copy = copy.deepcopy(df_vecs_bodenschutz) 
df_vecs_ressourcen_copy = copy.deepcopy(df_vecs_ressourcen) 
df_vecs_digitalisierung_copy = copy.deepcopy(df_vecs_digitalisierung)

# %%
# Create a dictionary mapping the year to the decade
def get_decade(year):
    if 1946 <= year <= 1955:
        return "1946-1955"
    elif 1956 <= year <= 1965:
        return "1956-1965"
    elif 1966 <= year <= 1975:
        return "1966-1975"
    elif 1976 <= year <= 1985:
        return "1976-1985"
    elif 1986 <= year <= 1995:
        return "1986-1995"
    elif 1996 <= year <= 2005:
        return "1996-2005"
    elif 2006 <= year <= 2014:
        return "2006-2014"
    else:
        return None

# %%
df_vecs_umwelt_copy['decade'] = df_vecs_umwelt_copy["year"].apply(lambda x: get_decade(x))
df_vecs_umweltschutz_copy['decade'] = df_vecs_umweltschutz_copy["year"].apply(lambda x: get_decade(x)) 
df_vecs_klimaschutz_copy['decade'] = df_vecs_klimaschutz_copy["year"].apply(lambda x: get_decade(x)) 
df_vecs_naturschutz_copy['decade'] = df_vecs_naturschutz_copy["year"].apply(lambda x: get_decade(x)) 
df_vecs_gesundheit_copy['decade'] = df_vecs_gesundheit_copy["year"].apply(lambda x: get_decade(x))
df_vecs_nachhaltigkeit_copy['decade'] = df_vecs_nachhaltigkeit_copy["year"].apply(lambda x: get_decade(x)) 
df_vecs_klimawandel_copy['decade'] = df_vecs_klimawandel_copy["year"].apply(lambda x: get_decade(x))
df_vecs_natur_copy['decade'] = df_vecs_natur_copy["year"].apply(lambda x: get_decade(x))
df_vecs_raumordnung_copy['decade'] = df_vecs_raumordnung_copy["year"].apply(lambda x: get_decade(x)) 
df_vecs_umweltpolitik_copy['decade'] = df_vecs_umweltpolitik_copy["year"].apply(lambda x: get_decade(x)) 
df_vecs_arbeitsschutz_copy['decade'] = df_vecs_arbeitsschutz_copy["year"].apply(lambda x: get_decade(x))
df_vecs_energiewende_copy['decade'] = df_vecs_energiewende_copy["year"].apply(lambda x: get_decade(x))
df_vecs_energiepolitik_copy['decade'] = df_vecs_energiepolitik_copy["year"].apply(lambda x: get_decade(x))
df_vecs_ökologische_copy['decade'] = df_vecs_ökologische_copy["year"].apply(lambda x: get_decade(x))
df_vecs_soziales_copy['decade'] = df_vecs_soziales_copy["year"].apply(lambda x: get_decade(x))
df_vecs_tierschutz_copy['decade'] = df_vecs_tierschutz_copy["year"].apply(lambda x: get_decade(x)) 
df_vecs_umweltbundesamt_copy['decade'] = df_vecs_umweltbundesamt_copy["year"].apply(lambda x: get_decade(x)) 
df_vecs_mobilität_copy['decade'] = df_vecs_mobilität_copy["year"].apply(lambda x: get_decade(x))
df_vecs_gewässerschutz_copy['decade'] = df_vecs_gewässerschutz_copy["year"].apply(lambda x: get_decade(x))
df_vecs_raumplanung_copy['decade'] = df_vecs_raumplanung_copy["year"].apply(lambda x: get_decade(x)) 
df_vecs_agrar_copy['decade'] = df_vecs_agrar_copy["year"].apply(lambda x: get_decade(x))
df_vecs_landnutzung_copy['decade'] = df_vecs_landnutzung_copy["year"].apply(lambda x: get_decade(x)) 
df_vecs_umweltfragen_copy['decade'] = df_vecs_umweltfragen_copy["year"].apply(lambda x: get_decade(x)) 
df_vecs_datenschutz_copy['decade'] = df_vecs_datenschutz_copy["year"].apply(lambda x: get_decade(x)) 
df_vecs_bodenschutz_copy['decade'] = df_vecs_bodenschutz_copy["year"].apply(lambda x: get_decade(x)) 
df_vecs_ressourcen_copy['decade'] = df_vecs_ressourcen_copy["year"].apply(lambda x: get_decade(x)) 
df_vecs_digitalisierung_copy['decade'] = df_vecs_digitalisierung_copy["year"].apply(lambda x: get_decade(x))

# %%
df_mean_umwelt_decade = df_vecs_umwelt_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_umweltschutz_decade = df_vecs_umweltschutz_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index() 
df_mean_klimaschutz_decade = df_vecs_klimaschutz_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index() 
df_mean_naturschutz_decade = df_vecs_naturschutz_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index() 
df_mean_gesundheit_decade = df_vecs_gesundheit_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_nachhaltigkeit_decade = df_vecs_nachhaltigkeit_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index() 
df_mean_klimawandel_decade = df_vecs_klimawandel_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_natur_decade = df_vecs_natur_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_raumordnung_decade = df_vecs_raumordnung_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index() 
df_mean_umweltpolitik_decade = df_vecs_umweltpolitik_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_arbeitsschutz_decade = df_vecs_arbeitsschutz_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_energiewende_decade = df_vecs_energiewende_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_energiepolitik_decade = df_vecs_energiepolitik_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_ökologische_decade = df_vecs_ökologische_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_soziales_decade = df_vecs_soziales_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_tierschutz_decade = df_vecs_tierschutz_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index() 
df_mean_umweltbundesamt_decade = df_vecs_umweltbundesamt_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index() 
df_mean_mobilität_decade = df_vecs_mobilität_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_gewässerschutz_decade = df_vecs_gewässerschutz_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_raumplanung_decade = df_vecs_raumplanung_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_agrar_decade = df_vecs_agrar_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()
df_mean_landnutzung_decade = df_vecs_landnutzung_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index() 
df_mean_umweltfragen_decade = df_vecs_umweltfragen_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index() 
df_mean_datenschutz_decade = df_vecs_datenschutz_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index() 
df_mean_bodenschutz_decade = df_vecs_bodenschutz_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index() 
df_mean_ressourcen_decade = df_vecs_ressourcen_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index() 
df_mean_digitalisierung_decade = df_vecs_digitalisierung_copy.groupby('decade').agg({'word': 'first', 'vector': lambda x: np.mean(np.array(x.tolist()), axis=0)}).reset_index()

# %%
#dropping the first decade of "Klimawandel" to avoid gaps in data visualization
#first_row = df_mean_klimawandel_decade.iloc[0]
df_mean_klimawandel_decade_without_gap = df_mean_klimawandel_decade.drop(0)

# %%
#df_mean_klimawandel_decade_without_gap

# %%
df_mean_decade_concat = pd.concat([df_mean_umwelt_decade,
                                  df_mean_umweltschutz_decade,
                                  df_mean_klimaschutz_decade,
                                 df_mean_naturschutz_decade,
                                  df_mean_gesundheit_decade,
                                  df_mean_nachhaltigkeit_decade,
                                  df_mean_klimawandel_decade_without_gap,
                                   #df_mean_klimawandel_decade,
                                  df_mean_natur_decade,
                                  df_mean_raumordnung_decade,
                                  df_mean_umweltpolitik_decade,
                                   df_mean_arbeitsschutz_decade,
                                   df_mean_energiewende_decade,
                                   df_mean_energiepolitik_decade,
                                   df_mean_ökologische_decade,
                                   df_mean_soziales_decade,
                                   df_mean_tierschutz_decade,
                                   df_mean_umweltbundesamt_decade,
                                   df_mean_mobilität_decade,
                                   df_mean_gewässerschutz_decade,
                                   df_mean_raumplanung_decade,
                                   df_mean_agrar_decade,
                                   df_mean_landnutzung_decade,
                                   df_mean_umweltfragen_decade,
                                   df_mean_datenschutz_decade,
                                   df_mean_bodenschutz_decade,
                                   df_mean_ressourcen_decade,
                                   df_mean_digitalisierung_decade ], axis=0)

# %%
def create_df_decade(df):
    df_year = pd.DataFrame(columns=['decade', 'word', 'vector'])
    for year, df_year_i in df.groupby('decade'):
        df_year_i = df_year_i.groupby('word').agg({'vector': np.mean}).reset_index()
        df_year_i['decade'] = year
        df_year = pd.concat([df_year, df_year_i], axis=0)
    return df_year

# %%
df_mean_decade = df_mean_decade_concat.groupby('decade').apply(create_df_decade)

# %%
#df_mean_decade.head()
#save_df = df_mean_decade.to_csv('df_mean_decade_umwelt.csv', index=False)

# %% [markdown]
# <br>

# %% [markdown]
# ### 2.3.2. Cosine Similarity: calculating mean vectors for decades

# %%
# Get a list of all unique words
unique_words = df_mean_decade['word'].unique()

# Get a list of all unique decades
unique_decades = df_mean_decade['decade'].unique()

cosine_similarities_decade = {}
for i, decade1 in enumerate(unique_decades):
    for word1 in unique_words:
        vector1 = df_mean_decade.loc[(df_mean_decade['word'] == word1) & (df_mean_decade['decade'] == decade1), 'vector'].values
        if len(vector1) == 0:
            continue
        vector1 = vector1[0]
        for j, decade2 in enumerate(unique_decades[i+1:]):
           #  Check if the difference between the decades is equal to 10
            if int(decade2[:4]) - int(decade1[:4]) != 10:
                continue
            for word2 in unique_words:
                vector2 = df_mean_decade.loc[(df_mean_decade['word'] == word2) & (df_mean_decade['decade'] == decade2), 'vector'].values
                if len(vector2) == 0:
                    continue
                vector2 = vector2[0]
                dot_product = np.dot(vector1, vector2)
                magnitude_vector1 = np.linalg.norm(vector1)
                magnitude_vector2 = np.linalg.norm(vector2)
                cosine_similarity = dot_product / (magnitude_vector1 * magnitude_vector2)
                cosine_similarities_decade[f"{word1}_{decade1}_{word2}_{decade2}"] = cosine_similarity
cosine_similarities_decade = pd.DataFrame.from_dict(cosine_similarities_decade, orient='index', columns=['cosine_similarity'])
cosine_similarities_decade = cosine_similarities_decade.reset_index()
cosine_similarities_decade['word1'], cosine_similarities_decade['decade1'], cosine_similarities_decade['word2'], cosine_similarities_decade['decade2'] = zip(*cosine_similarities_decade['index'].str.split('_'))
cosine_similarities_decade[['decade1', 'decade2']] = cosine_similarities_decade[['decade1', 'decade2']].astype(str)

# %%
cosine_similarities_decade
# Out:
#                                                  index  cosine_similarity  \
# 0                      Agrar_1946-1955_Agrar_1956-1965           0.884621
# 1              Agrar_1946-1955_Arbeitsschutz_1956-1965           0.560458
# 2             Agrar_1946-1955_Energiepolitik_1956-1965           0.900117
# 3                 Agrar_1946-1955_Gesundheit_1956-1965           0.847743
# 4                      Agrar_1946-1955_Natur_1956-1965           0.862162
# ...                                                ...                ...
# 2465      Energiewende_1996-2005_Klimaschutz_2006-2014           0.834182
# 2466      Energiewende_1996-2005_Klimawandel_2006-2014           0.819688
# 2467   Energiewende_1996-2005_Nachhaltigkeit_2006-2014           0.856119
# 2468  Energiewende_1996-2005_Digitalisierung_2006-2014           0.890677
# 2469     Energiewende_1996-2005_Energiewende_2006-2014           0.949210
#
#              word1    decade1            word2    decade2
# ...

# %% [markdown]
# ### 2.3.3. Creating Word2Word DataFrame with only Cosine Similarities to ONESELF

# %%
# Filter the rows where the word1 and word2 are the same and decade1 is consecutive to decade2
df = cosine_similarities_decade[(cosine_similarities_decade["word1"] == cosine_similarities_decade["word2"]) & (cosine_similarities_decade["decade1"] == cosine_similarities_decade["decade1"])]

# Reset the index of the filtered dataframe
#df = df.reset_index(drop=True)

# Print the filtered dataframe
df
# Out:
#                                                   index  cosine_similarity  \
# 0                       Agrar_1946-1955_Agrar_1956-1965           0.884621
# 12      Arbeitsschutz_1946-1955_Arbeitsschutz_1956-1965           0.529525
# 24    Energiepolitik_1946-1955_Energiepolitik_1956-1965           0.615499
# 36            Gesundheit_1946-1955_Gesundheit_1956-1965           0.975880
# 59                      Natur_1946-1955_Natur_1956-1965           0.986084
# ...                                                 ...                ...
# 2361        Klimaschutz_1996-2005_Klimaschutz_2006-2014           0.981243
# 2388        Klimawandel_1996-2005_Klimawandel_2006-2014           0.977174
# 2415  Nachhaltigkeit_1996-2005_Nachhaltigkeit_2006-2014           0.989291
# 2442  Digitalisierung_1996-2005_Digitalisierung_2006...           0.922013
# 2469      Energiewende_1996-2005_Energiewende_2006-2014           0.949210
#
#                 word1    decade1            word2    decade2
# ...

# %%
#creating the x axis label
df["x_axis_label"] = df["decade2"].apply(lambda x: "bis "+str(int(x[-4:])-1) if x == "1946-1955" else x)
df["x_axis_label"] = df["x_axis_label"].apply(lambda x: "bis "+str(int(x[-4:])+1) if x == "1956-1965" else x)
df["x_axis_label"] = df["x_axis_label"].apply(lambda x: "bis "+str(int(x[-4:])+1) if x == "1966-1975" else x)
df["x_axis_label"] = df["x_axis_label"].apply(lambda x: "bis "+str(int(x[-4:])+1) if x == "1976-1985" else x)
df["x_axis_label"] = df["x_axis_label"].apply(lambda x: "bis "+str(int(x[-4:])+1) if x == "1986-1995" else x)
df["x_axis_label"] = df["x_axis_label"].apply(lambda x: "bis "+str(int(x[-4:])+1) if x == "1996-2005" else x)
df["x_axis_label"] = df["x_axis_label"].apply(lambda x: "bis "+str(int(x[-4:])+1) if x == "2006-2014" else x)
# Out:
# /tmp/ipykernel_71/1088746583.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_71/1088746583.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_71/1088746583.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# <b>!For scientific corecctness we have to eluminate words out of hte calculation, which are not represented in every consecutive decade!</b>

# %%
to_eliminate = ['Bodenschutz', 'Gewässerschutz', 'Landnutzung', 'Raumplanung']
df = df[~df['word1'].isin(to_eliminate)]

# %%
df
# Out:
#                                                   index  cosine_similarity  \
# 0                       Agrar_1946-1955_Agrar_1956-1965           0.884621
# 12      Arbeitsschutz_1946-1955_Arbeitsschutz_1956-1965           0.529525
# 24    Energiepolitik_1946-1955_Energiepolitik_1956-1965           0.615499
# 36            Gesundheit_1946-1955_Gesundheit_1956-1965           0.975880
# 59                      Natur_1946-1955_Natur_1956-1965           0.986084
# ...                                                 ...                ...
# 2361        Klimaschutz_1996-2005_Klimaschutz_2006-2014           0.981243
# 2388        Klimawandel_1996-2005_Klimawandel_2006-2014           0.977174
# 2415  Nachhaltigkeit_1996-2005_Nachhaltigkeit_2006-2014           0.989291
# 2442  Digitalisierung_1996-2005_Digitalisierung_2006...           0.922013
# 2469      Energiewende_1996-2005_Energiewende_2006-2014           0.949210
#
# ...

# %%
quantile_5 = df["cosine_similarity"].quantile(0.05)

# %%
quantile_5
# Out:
# 0.6130573043902565

# %%
df.loc[df["cosine_similarity"] <= quantile_5 ]["word2"].unique()
# Out:
# array(['Arbeitsschutz', 'Raumordnung', 'Tierschutz'], dtype=object)

# %% [markdown]
# ## 2.3.4. Visualization: Similarity Development between WOI to Themselfes over the Years

# %%
import plotly.express as px

fig = px.line(df, x='x_axis_label', y='cosine_similarity', color='word2', color_discrete_map=custom_color_map, title = "Similarity Developement of WOI to Oneself over Decades")
fig.update_yaxes(range=[0, 1])
fig.add_shape(
    type = 'line',
    y0=quantile_5,
    y1=quantile_5,
    x0=df['x_axis_label'].min(),
    x1=df['x_axis_label'].max(),
    yref='paper',
    xref='x',
    line=dict(color='gray', dash='dash')
)
fig.add_annotation(
    x='2006-2014',
    y=quantile_5,
    text=f'5% quantile: {quantile_5:.5f}',
    xref='x',
    yref='y',
    showarrow=False,
    font=dict(color='gray'))
    #fig.show()
fig.write_html("cosine_similarity_umwelt_word2word_decade.html")
